# %%
# la fuente del codigo es: https://github.com/sankit1/cv-tricks.com

#importa la clase conjuntoDeDatos, esta obtiene las imagenes de entrenamiento por cada subcarpeta o clases de imagenes. 
import CNN
import conjuntoDeDatos
import tensorflow as tf
from datetime import timedelta
import random
import os
import math
import time
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# instanciar CNN
cnncapas = CNN.CNN()

# Agregar semilla para que la inicialización aleatoria sea consistente
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

""" tamanoLotePorIteracion (batch-size) """
tamanoLotePorIteracion = 32

#Preparar la data de entrada
#Existen dos calses, perros y gatos.
clases = ['dermatitis','melanoma','seborrheic_keratosis']
numeroClases = len(clases)

# leyendo las imagenes de entrada
# datos de entrenamiento: deberia ser usado el 80% de las imagenes
# datos de validacion: deberia ser usado el 20% de las imagenes, estas imagenes deben quedar fuera del conjunto de datos de entrenamiento, este conjunto de datos es necesario para calcular la exactitud del modelo.
# datos de prueba, este conjunto de datos es utilizado para probar el modelo, despue de haber entrenado el modelo funciona bien, pero cuando las imagenes son convertidas a un tamaño muy reducido el model puede fallar, a este termino se le conoce como sobre sobreajuste(Overfitting), el sobre ajuste puede ser probocado por el fondo de las imagenes.

# tamanoDeDataDeValidacion automaticamente se usara el 20% de todas las imagenes para la validacion.
tamanoDeDataDeValidacion = 0.2

# El mamaño de las imagenes es de 128 pixeles por 128.
tamanoDeImagenes = 128

# el numero de canales representa que la imagenen tiene los tres colores RGB
numeroDeColoresPorImagen = 3

# la ruta de datos de entrenamiento es la carpeta donde se encuentran los conjuntos de imagenes de entrenamiento y validacion
rutaDeDatosDeEntrenamiento=os.path.join(os.path.realpath('.'),'dataset/trainTemp/')
print("Ruta de datos de entrenamiento "+str(rutaDeDatosDeEntrenamiento))
# Cargar las imagenes de entrenamiento y validacion con sus etiquetas en memoria usando openCV para ser usadas durante el proceso de entrenamiento.
data = conjuntoDeDatos.leerDatosDeEntrenamiento(rutaDeDatosDeEntrenamiento, tamanoDeImagenes, clases, tamanoDeDataDeValidacion)

print("Completado el proceso de lecturada de imagenes.")
print("Numero de imagenes en el conjunto de entrenamiento:\t{}".format(len(data.entrenamiento.etiquetas)))
print("Numero de imagenes en el conjunto de validacion :\t{}".format(len(data.validacion.etiquetas)))
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/lil.py:19: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _csparsetools
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/csgraph/__init__.py:165: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._shortest_path import shortest_path, floyd_warshall, dijkstra,\
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/csgraph/_validation.py:5: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._tools import csgraph_to_dense, csgraph_from_dense,\
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/csgraph/__init__.py:167: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._traversal import breadth_first_order, depth_first_order, \
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/csgraph/__init__.py:169: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._min_spanning_tree import minimum_spanning_tree
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/csgraph/__init__.py:170: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._reordering import reverse_cuthill_mckee, maximum_bipartite_matching, \
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/__init__.py:9: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .murmurhash import murmurhash3_32
# /usr/local/lib/python2.7/dist-packages/scipy/linalg/basic.py:17: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._solve_toeplitz import levinson
# /usr/local/lib/python2.7/dist-packages/scipy/linalg/__init__.py:207: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._decomp_update import *
# /usr/local/lib/python2.7/dist-packages/scipy/special/__init__.py:640: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ufuncs import *
# /usr/local/lib/python2.7/dist-packages/scipy/special/_ellip_harm.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ellip_harm_2 import _ellipsoid, _ellipsoid_norm
# Ruta de datos de entrenamiento /notebooks/CNN/dataset/trainTemp/
# clase dermatitis, indice 0, path /notebooks/CNN/dataset/trainTemp/dermatitis.*.jpg, files number 287, max images 287
# clase melanoma, indice 1, path /notebooks/CNN/dataset/trainTemp/melanoma.*.jpg, files number 298, max images 298
# clase seborrheic_keratosis, indice 2, path /notebooks/CNN/dataset/trainTemp/seborrheic_keratosis.*.jpg, files number 185, max images 185
# Finalizando de obtener imagenes
# Completado el proceso de lecturada de imagenes.
# Numero de imagenes en el conjunto de entrenamiento:	612
# Numero de imagenes en el conjunto de validacion :	153

# %%
session = tf.Session()
tensorDeEntrada = tf.placeholder(tf.float32, shape=[None, tamanoDeImagenes,tamanoDeImagenes,numeroDeColoresPorImagen], name='tensorDeEntrada')

## Etiquetas
tensorDeClases = tf.placeholder(tf.float32, shape=[None, numeroClases], name='tensorDeClases')
tensorDeClasesAplanado = tf.argmax(tensorDeClases, dimension=1)

# %%
##Parametros graficos de red
# El parametro mas importante en una red convolucional es el tamaño del filtro de cada neurona.  
# Por ejemplo si entrada de la neurona es una imagen de 32x32x3, esto significa que la imagen tiene 
# una dimension de 32x32 (alto x ancho) pixeles y contiene 3 colores RGB, entonces el filtro significa 
# que se convertiran las imagenes a 5x5x3, es decir 5x5 (alto x ancho) y 3 representa el numero de colores RGB.

#Configuracion de la primera capa oculta, el tamaño del filtro es 3 y el numero de filtros es 32

#capaConvolucional1 = cnncapas.(tensorDeEntrada,3,3,32)
capaConvolucional1 = cnncapas.crearCapaConvolucional(
                        tensorDeEntrada=tensorDeEntrada,
                        numeroDeCanales=numeroDeColoresPorImagen,
                        tamanoDelFiltro=3,
                        numeroDeFiltros=32)

#capaConvolucional2 = (capaConvolucional1,32,3,32)
capaConvolucional2 = cnncapas.crearCapaConvolucional(
                        tensorDeEntrada=capaConvolucional1,
                        numeroDeCanales=32,
                        tamanoDelFiltro=3,
                        numeroDeFiltros=32)

#capaConvolucional3= cnncapas.(capaConvolucional2,32,3,64)
capaConvolucional3= cnncapas.crearCapaConvolucional(
                        tensorDeEntrada=capaConvolucional2,
                        numeroDeCanales=32,
                        tamanoDelFiltro=3,
                        numeroDeFiltros=64)

capaPlana = cnncapas.crearCapaAplanada(capaConvolucional3)

capaTotalmenteConectada1 = cnncapas.crearCapaTotalmenteConectada(
                            tensorDeEntrada=capaPlana,
                            num_inputs=capaPlana.get_shape()[1:4].num_elements(),
                            num_outputs=128,
                            use_relu=True)

capaTotalmenteConectada2 = cnncapas.crearCapaTotalmenteConectada(
                            tensorDeEntrada=capaTotalmenteConectada1,
                            num_inputs=128,
                            num_outputs=numeroClases,
                            use_relu=False)

# %%
#Softmax: Calcula las activaciones softmax, los argumentos de la funcion son:
## logits: es un tensor no vacio.  Puede ser uno de los siguientes tipos "half, float32, float64"
## dim: la dimension softmax puede ser realidad en: el valor default es -1, el cual indica la ultima dimension.
## name: es opcional, representa el nombre de la operacion.

## retorna: un tensor, tiene el mismo tipo y forma que logits.

# la variable ResultadoDeProbabilidadPorClase guarda los valores de la ultima capa (capaTotalmenteConectada2) y obtiene por medio de la funcion softmax los valores de probabilidad en un rango de 0-1
prediccionDeProbabilidadPorClase = tf.nn.softmax(
                    capaTotalmenteConectada2,
                    name='prediccionDeProbabilidadPorClase')

# la variable ResultadoDeProbabilidadPorClase guarda la probabilidad de cada clase aplanda es decir en un vector.
prediccionDeProbabilidadPorClaseAplanada = tf.argmax(
                    prediccionDeProbabilidadPorClase, 
                    dimension=1)

# tf.Session es una clase para correr operaciones de tensorflow
# Un objetivo de una sesion es encapsular el entorno en el cual los objectos (operaciones) son ejecutados y los objectos (Tensores) son evaluados.

#inicializar las variables.
session.run(tf.global_variables_initializer())

#Entropia cruzada:
entropiaCruzada = tf.nn.softmax_cross_entropy_with_logits(
                    logits=capaTotalmenteConectada2,
                    labels=tensorDeClases)

perdidaTotalDeErrorEnClasificacion = tf.reduce_mean(entropiaCruzada)

optimizador = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(perdidaTotalDeErrorEnClasificacion)

correccionDePrediccion = tf.equal(prediccionDeProbabilidadPorClaseAplanada, 
                                  tensorDeClasesAplanado)

exactitudDelModelo = tf.reduce_mean(tf.cast(correccionDePrediccion, tf.float32))

#inicializar las variables.
tf.summary.FileWriter("/tmp/tensorflow/", session.graph)
session.run(tf.global_variables_initializer())

# %%
def mostrarProgreso(epoca, entrenamiento_imagenesYetiquetasPorEpoca, validacion_imagenesYetiquetasPorEpoca, perdidaDeValidacion):
    exactitudDeEntrenamiento = session.run(exactitudDelModelo, feed_dict=entrenamiento_imagenesYetiquetasPorEpoca)
    exactitudDeValidacion = session.run(exactitudDelModelo, feed_dict=validacion_imagenesYetiquetasPorEpoca)
    msg = "Training epoca {0} --- Exactitud del entranamiento: {1:>6.1%}, Exactitud de validacion: {2:>6.1%},  perida de validacion: {3:.3f}"
    print(msg.format(epoca + 1, exactitudDeEntrenamiento, exactitudDeValidacion, perdidaDeValidacion))

recuentoIteraciones = 0

""" batch-size (tamaño del lote por iteracion), cuando se entrena una red no se  alimenta con todo el conjunto de datos, se hace por medio de iteracion y cada iteracion tiene un tamaño, frecuentemente es 16 o 32"""
saver = tf.train.Saver()

def entrenarModelo(totalIteraciones):
    print("---------------- FUNCION DE ENTRENAMIENTO  ------------------")
    print("numero de imagenes para entrenamiento "+str(data.entrenamiento.recuento))

    global recuentoIteraciones
    for iteracion in range(recuentoIteraciones,recuentoIteraciones + totalIteraciones):
        if((iteracion+1) % 100 == 0):
            print("-- iteracion # "+str(iteracion+1)+" con imagenes # "+str(tamanoLotePorIteracion))
        
        entrenamientoPaquete_imagenes, entrenamientoPaquete_etiquetas, entrenamientoPaquete_nombres, entrenamientoPaquete_clases = data.entrenamiento.siguienteLote(tamanoLotePorIteracion)
        validacionPaquete_imagenes, validacionPaquete_etiquetas, validacionPaquete_nombres, validacionPaquete_clases = data.validacion.siguienteLote(tamanoLotePorIteracion)

        entrenamiento_imagenesYetiquetasPorEpoca = {tensorDeEntrada: entrenamientoPaquete_imagenes,tensorDeClases: entrenamientoPaquete_etiquetas}
        validacion_imagenesYetiquetasPorEpoca = {tensorDeEntrada: validacionPaquete_imagenes,tensorDeClases: validacionPaquete_etiquetas}
        
        session.run(optimizador, feed_dict=entrenamiento_imagenesYetiquetasPorEpoca)

        if iteracion % int(data.entrenamiento.recuento/tamanoLotePorIteracion) == 0:
            print("mostrar epoca "+str(int(data.entrenamiento.recuento/tamanoLotePorIteracion)))
            perdidadDeValidacion = session.run(perdidaTotalDeErrorEnClasificacion, feed_dict=validacion_imagenesYetiquetasPorEpoca)

            """ epoca (epoch) una epoca contiene un conjunto de iteracion que alimentan el modelo """
            epoca = int(iteracion / int(data.entrenamiento.recuento/tamanoLotePorIteracion))

            mostrarProgreso(epoca, entrenamiento_imagenesYetiquetasPorEpoca, validacion_imagenesYetiquetasPorEpoca, perdidadDeValidacion)
            saver.save(session, './model/model.meta')
            #saver.save(session, './model/codigoModificado/dogs-cats-model_20_04_2018_v.1.meta')

    recuentoIteraciones += totalIteraciones

entrenarModelo(totalIteraciones=2000)
print("Fin del entrenamiento")
# Out:
# ---------------- FUNCION DE ENTRENAMIENTO  ------------------
# numero de imagenes para entrenamiento 612
# mostrar epoca 19
# Training epoca 1 --- Exactitud del entranamiento:  46.9%, Exactitud de validacion:  46.9%,  perida de validacion: 1.084
# mostrar epoca 19
# Training epoca 2 --- Exactitud del entranamiento:  62.5%, Exactitud de validacion:  50.0%,  perida de validacion: 1.073
# mostrar epoca 19
# Training epoca 3 --- Exactitud del entranamiento:  65.6%, Exactitud de validacion:  46.9%,  perida de validacion: 1.016
# mostrar epoca 19
# Training epoca 4 --- Exactitud del entranamiento:  71.9%, Exactitud de validacion:  62.5%,  perida de validacion: 0.806
# mostrar epoca 19
# Training epoca 5 --- Exactitud del entranamiento:  81.2%, Exactitud de validacion:  81.2%,  perida de validacion: 0.651
# mostrar epoca 19
# Training epoca 6 --- Exactitud del entranamiento:  81.2%, Exactitud de validacion:  71.9%,  perida de validacion: 0.766
# -- iteracion # 100 con imagenes # 32
# mostrar epoca 19
# Training epoca 7 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  68.8%,  perida de validacion: 0.896
# mostrar epoca 19
# Training epoca 8 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  75.0%,  perida de validacion: 0.592
# mostrar epoca 19
# Training epoca 9 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  87.5%,  perida de validacion: 0.427
# mostrar epoca 19
# Training epoca 10 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  71.9%,  perida de validacion: 0.701
# mostrar epoca 19
# Training epoca 11 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  68.8%,  perida de validacion: 0.843
# -- iteracion # 200 con imagenes # 32
# mostrar epoca 19
# Training epoca 12 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  75.0%,  perida de validacion: 0.497
# mostrar epoca 19
# Training epoca 13 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  84.4%,  perida de validacion: 0.378
# mostrar epoca 19
# Training epoca 14 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  68.8%,  perida de validacion: 0.642
# mostrar epoca 19
# Training epoca 15 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  68.8%,  perida de validacion: 0.851
# mostrar epoca 19
# Training epoca 16 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  84.4%,  perida de validacion: 0.401
# -- iteracion # 300 con imagenes # 32
# mostrar epoca 19
# Training epoca 17 --- Exactitud del entranamiento:  78.1%, Exactitud de validacion:  90.6%,  perida de validacion: 0.347
# mostrar epoca 19
# Training epoca 18 --- Exactitud del entranamiento:  81.2%, Exactitud de validacion:  68.8%,  perida de validacion: 0.612
# mostrar epoca 19
# Training epoca 19 --- Exactitud del entranamiento:  90.6%, Exactitud de validacion:  71.9%,  perida de validacion: 0.912
# mostrar epoca 19
# Training epoca 20 --- Exactitud del entranamiento:  90.6%, Exactitud de validacion:  84.4%,  perida de validacion: 0.350
# mostrar epoca 19
# Training epoca 21 --- Exactitud del entranamiento:  90.6%, Exactitud de validacion:  96.9%,  perida de validacion: 0.338
# -- iteracion # 400 con imagenes # 32
# mostrar epoca 19
# Training epoca 22 --- Exactitud del entranamiento:  90.6%, Exactitud de validacion:  75.0%,  perida de validacion: 0.585
# mostrar epoca 19
# Training epoca 23 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  71.9%,  perida de validacion: 0.972
# mostrar epoca 19
# Training epoca 24 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  84.4%,  perida de validacion: 0.317
# mostrar epoca 19
# Training epoca 25 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  96.9%,  perida de validacion: 0.316
# mostrar epoca 19
# Training epoca 26 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  78.1%,  perida de validacion: 0.549
# mostrar epoca 19
# Training epoca 27 --- Exactitud del entranamiento:  81.2%, Exactitud de validacion:  68.8%,  perida de validacion: 0.927
# -- iteracion # 500 con imagenes # 32
# mostrar epoca 19
# Training epoca 28 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  81.2%,  perida de validacion: 0.317
# mostrar epoca 19
# Training epoca 29 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  90.6%,  perida de validacion: 0.290
# mostrar epoca 19
# Training epoca 30 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  84.4%,  perida de validacion: 0.554
# mostrar epoca 19
# Training epoca 31 --- Exactitud del entranamiento:  84.4%, Exactitud de validacion:  68.8%,  perida de validacion: 0.923
# mostrar epoca 19
# Training epoca 32 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  84.4%,  perida de validacion: 0.308
# -- iteracion # 600 con imagenes # 32
# mostrar epoca 19
# Training epoca 33 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  90.6%,  perida de validacion: 0.269
# mostrar epoca 19
# Training epoca 34 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  84.4%,  perida de validacion: 0.551
# mostrar epoca 19
# Training epoca 35 --- Exactitud del entranamiento:  87.5%, Exactitud de validacion:  68.8%,  perida de validacion: 0.967
# mostrar epoca 19
# Training epoca 36 --- Exactitud del entranamiento:  90.6%, Exactitud de validacion:  84.4%,  perida de validacion: 0.280
# mostrar epoca 19
# Training epoca 37 --- Exactitud del entranamiento:  93.8%, Exactitud de validacion:  90.6%,  perida de validacion: 0.277
# -- iteracion # 700 con imagenes # 32
# mostrar epoca 19
# Training epoca 38 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  84.4%,  perida de validacion: 0.560
# mostrar epoca 19
# Training epoca 39 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  68.8%,  perida de validacion: 1.018
# mostrar epoca 19
# Training epoca 40 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  87.5%,  perida de validacion: 0.282
# mostrar epoca 19
# Training epoca 41 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  93.8%,  perida de validacion: 0.295
# mostrar epoca 19
# Training epoca 42 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  84.4%,  perida de validacion: 0.581
# mostrar epoca 19
# Training epoca 43 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  68.8%,  perida de validacion: 1.066
# -- iteracion # 800 con imagenes # 32
# mostrar epoca 19
# Training epoca 44 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.293
# mostrar epoca 19
# Training epoca 45 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  93.8%,  perida de validacion: 0.313
# mostrar epoca 19
# Training epoca 46 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.600
# mostrar epoca 19
# Training epoca 47 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  68.8%,  perida de validacion: 1.113
# mostrar epoca 19
# Training epoca 48 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 0.309
# -- iteracion # 900 con imagenes # 32
# mostrar epoca 19
# Training epoca 49 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  93.8%,  perida de validacion: 0.329
# mostrar epoca 19
# Training epoca 50 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.628
# mostrar epoca 19
# Training epoca 51 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  68.8%,  perida de validacion: 1.161
# mostrar epoca 19
# Training epoca 52 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.329
# mostrar epoca 19
# Training epoca 53 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  93.8%,  perida de validacion: 0.323
# -- iteracion # 1000 con imagenes # 32
# mostrar epoca 19
# Training epoca 54 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.680
# mostrar epoca 19
# Training epoca 55 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  78.1%,  perida de validacion: 1.255
# mostrar epoca 19
# Training epoca 56 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  81.2%,  perida de validacion: 0.404
# mostrar epoca 19
# Training epoca 57 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  81.2%,  perida de validacion: 0.341
# mostrar epoca 19
# Training epoca 58 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  84.4%,  perida de validacion: 0.764
# -- iteracion # 1100 con imagenes # 32
# mostrar epoca 19
# Training epoca 59 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  78.1%,  perida de validacion: 1.517
# mostrar epoca 19
# Training epoca 60 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  78.1%,  perida de validacion: 0.619
# mostrar epoca 19
# Training epoca 61 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  84.4%,  perida de validacion: 0.397
# mostrar epoca 19
# Training epoca 62 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  81.2%,  perida de validacion: 0.915
# mostrar epoca 19
# Training epoca 63 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  71.9%,  perida de validacion: 1.917
# mostrar epoca 19
# Training epoca 64 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  71.9%,  perida de validacion: 1.049
# -- iteracion # 1200 con imagenes # 32
# mostrar epoca 19
# Training epoca 65 --- Exactitud del entranamiento:  96.9%, Exactitud de validacion:  81.2%,  perida de validacion: 0.416
# mostrar epoca 19
# Training epoca 66 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.795
# mostrar epoca 19
# Training epoca 67 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 1.519
# mostrar epoca 19
# Training epoca 68 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.521
# mostrar epoca 19
# Training epoca 69 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 0.232
# -- iteracion # 1300 con imagenes # 32
# mostrar epoca 19
# Training epoca 70 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 0.654
# mostrar epoca 19
# Training epoca 71 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 1.457
# mostrar epoca 19
# Training epoca 72 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.525
# mostrar epoca 19
# Training epoca 73 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  90.6%,  perida de validacion: 0.261
# mostrar epoca 19
# Training epoca 74 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.669
# -- iteracion # 1400 con imagenes # 32
# mostrar epoca 19
# Training epoca 75 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.486
# mostrar epoca 19
# Training epoca 76 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.524
# mostrar epoca 19
# Training epoca 77 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.238
# mostrar epoca 19
# Training epoca 78 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.688
# mostrar epoca 19
# Training epoca 79 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.557
# -- iteracion # 1500 con imagenes # 32
# mostrar epoca 19
# Training epoca 80 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.527
# mostrar epoca 19
# Training epoca 81 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.225
# mostrar epoca 19
# Training epoca 82 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.711
# mostrar epoca 19
# Training epoca 83 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.635
# mostrar epoca 19
# Training epoca 84 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.527
# mostrar epoca 19
# Training epoca 85 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.216
# -- iteracion # 1600 con imagenes # 32
# mostrar epoca 19
# Training epoca 86 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.739
# mostrar epoca 19
# Training epoca 87 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.706
# mostrar epoca 19
# Training epoca 88 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.539
# mostrar epoca 19
# Training epoca 89 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.213
# mostrar epoca 19
# Training epoca 90 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.759
# -- iteracion # 1700 con imagenes # 32
# mostrar epoca 19
# Training epoca 91 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.783
# mostrar epoca 19
# Training epoca 92 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.543
# mostrar epoca 19
# Training epoca 93 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.213
# mostrar epoca 19
# Training epoca 94 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.782
# mostrar epoca 19
# Training epoca 95 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.856
# -- iteracion # 1800 con imagenes # 32
# mostrar epoca 19
# Training epoca 96 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.556
# mostrar epoca 19
# Training epoca 97 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.208
# mostrar epoca 19
# Training epoca 98 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.795
# mostrar epoca 19
# Training epoca 99 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.922
# mostrar epoca 19
# Training epoca 100 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.564
# -- iteracion # 1900 con imagenes # 32
# mostrar epoca 19
# Training epoca 101 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  96.9%,  perida de validacion: 0.207
# mostrar epoca 19
# Training epoca 102 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.817
# mostrar epoca 19
# Training epoca 103 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  84.4%,  perida de validacion: 1.984
# mostrar epoca 19
# Training epoca 104 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  81.2%,  perida de validacion: 0.570
# mostrar epoca 19
# Training epoca 105 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  93.8%,  perida de validacion: 0.205
# mostrar epoca 19
# Training epoca 106 --- Exactitud del entranamiento: 100.0%, Exactitud de validacion:  87.5%,  perida de validacion: 0.835
# -- iteracion # 2000 con imagenes # 32
# Fin del entrenamiento
